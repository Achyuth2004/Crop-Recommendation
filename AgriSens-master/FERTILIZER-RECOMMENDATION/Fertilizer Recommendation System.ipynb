# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Fertilizer_Reccom.csv")

# %%
df.head()
# Out:
#    Nitrogen  Potassium  Phosphorous                Fertilizer Name
# 0        37          0            0                           Urea
# 1        12          0           36                            DAP
# 2         7          9           30  Fourteen-Thirty Five-Fourteen
# 3        22          0           20      Twenty Eight-Twenty Eight
# 4        35          0            0                           Urea

# %%
df.describe()
# Out:
#           Nitrogen    Potassium  Phosphorous
# count  2500.000000  2500.000000  2500.000000
# mean     19.326800     3.209200    18.090800
# std      11.669519     5.656486    13.256517
# min       4.000000     0.000000     0.000000
# 25%      10.000000     0.000000     9.000000
# 50%      14.000000     0.000000    18.000000
# 75%      24.000000     7.000000    30.000000
# max      42.000000    19.000000    42.000000

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['Fertilizer Name'].unique()
# Out:
# array(['Urea', 'DAP', 'Fourteen-Thirty Five-Fourteen',
#        'Twenty Eight-Twenty Eight', 'Seventeen-Seventeen-Seventeen',
#        'Twenty-Twenty', 'Ten-Twenty Six-Twenty Six'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
sns.countplot(x='Fertilizer Name', data = df)
# Out:
# <Axes: xlabel='Fertilizer Name', ylabel='count'>

# %%
X = df.drop(columns=['Fertilizer Name'])
y = df['Fertilizer Name']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.7,shuffle=True,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train[0]
# Out:
# array([-0.44635569, -0.57359586,  1.32591735])

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=100,criterion = 'gini', random_state=42)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(y_test,y_pred)
print(cm)
accuracy_score(y_test,y_pred)
# Out:
# [[26 18 10  5 26 18 35]
#  [27 13  3  4 23 14 27]
#  [ 7  6  1  1 18 11 26]
#  [ 6  7  3  1 10  6 10]
#  [28 17 13  4 25 25 41]
#  [18  9  8  5  9  9 32]
#  [20 19 10  4 27 23 42]]
# 0.156

# %%
from sklearn.preprocessing import LabelEncoder
encode_ferti = LabelEncoder()
df['Fertilizer Name']=encode_ferti.fit_transform(df['Fertilizer Name'])
#creating the dataframe
Fertilizer = pd.DataFrame(zip(encode_ferti.classes_,encode_ferti.transform(encode_ferti.classes_)),columns=['original','Encoded'])
Fertilizer = Fertilizer.set_index('original')
Fertilizer
# Out:
#                                Encoded
# original
# DAP                                  0
# Fourteen-Thirty Five-Fourteen        1
# Seventeen-Seventeen-Seventeen        2
# Ten-Twenty Six-Twenty Six            3
# Twenty Eight-Twenty Eight            4
# Twenty-Twenty                        5
# Urea                                 6

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(df.drop(columns=['Fertilizer Name']),df['Fertilizer Name'],test_size=0.2,random_state=1)
print('Shape of Splitting :')
print('x_train = {}, y_train = {}, x_test = {}, y_test = {}'.format(x_train.shape,y_train.shape,x_test.shape,y_test.shape))
# Out:
# Shape of Splitting :
# x_train = (2000, 3), y_train = (2000,), x_test = (500, 3), y_test = (500,)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 918 to 1061
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nitrogen     2000 non-null   int64
#  1   Potassium    2000 non-null   int64
#  2   Phosphorous  2000 non-null   int64
# dtypes: int64(3)
# memory usage: 62.5 KB

# %%
rand = RandomForestClassifier(random_state = 42)
rand.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred_rand = rand.predict(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

params = {
    'n_estimators':[300,400,500],
    'max_depth':[5,6,7],
    'min_samples_split':[2,5,8]
}
grid_rand = GridSearchCV(rand,params,cv=3,verbose=3,n_jobs=-1)

grid_rand.fit(x_train,y_train)

pred_rand = grid_rand.predict(x_test)

print(classification_report(y_test,pred_rand))

print('Best score : ',grid_rand.best_score_)
print('Best params : ',grid_rand.best_params_)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
#               precision    recall  f1-score   support
#
#            0       0.24      0.14      0.17        96
#            1       0.29      0.06      0.10        64
#            2       0.00      0.00      0.00        45
#            3       0.00      0.00      0.00        33
#            4       0.15      0.37      0.21        78
#            5       0.20      0.01      0.02        80
#            6       0.19      0.42      0.26       104
#
#     accuracy                           0.18       500
#    macro avg       0.15      0.14      0.11       500
# weighted avg       0.18      0.18      0.14       500
#
# Best score :  0.20999635317476398
# Best params :  {'max_depth': 5, 'min_samples_split': 8, 'n_estimators': 400}

# %%
import pickle
pickle_out = open('classifier1.pkl', 'wb')
pickle.dump(grid_rand,pickle_out)
pickle_out.close()

# %%
model = pickle.load(open('classifier1.pkl', 'rb'))
ans = model.predict([[80,67,145]])
if ans[0] == 0:
    print("TEN-TWENTY SIX-TWENTY SIX")
elif ans[0] == 1:
    print("Fourteen-Thirty Five-Fourteen")
elif ans[0] == 2:
    print("Seventeen-Seventeen-Seventeen")   
elif ans[0] == 3:
    print("TWENTY-TWENTY")
elif ans[0] == 4:
    print("TWENTY EIGHT-TWENTY EIGHT")
elif ans[0] == 5:
    print("DAP")
else:
    print("UREA")
# Out:
# TWENTY EIGHT-TWENTY EIGHT
